# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

print('Successfully imported modules from data_cleaner!')
# Out:
# Successfully imported modules from data_cleaner!

# %%
import pandas as pd
import numpy as np
from noventis import data_cleaner


sample_data = {
    'age': [25, 30, np.nan, 45, 50, 200, 28, 35, 29],
    'salary': [50000, 60000, 75000, 80000, 55000, 65000, 90000, np.nan, 72000],
    'city': ['Jakarta', 'Bandung', 'Jakarta', 'Surabaya', 'Bandung', 'Jakarta', 'Medan', 'Bandung', 'Jakarta'],
    'education': ['S1', 'S2', 'S1', 'S3', 'S1', 'S2', 'S1', np.nan, 'S1'],
    'satisfaction': [8, 9, 7, 9, 8, 3, 7, 8, 9] # Kolom target
}
df_raw = pd.DataFrame(sample_data)

print("Raw Data:")
df_raw.head()
# Out:
# Raw Data:
#     age   salary      city education  satisfaction
# 0  25.0  50000.0   Jakarta        S1             8
# 1  30.0  60000.0   Bandung        S2             9
# 2   NaN  75000.0   Jakarta        S1             7
# 3  45.0  80000.0  Surabaya        S3             9
# 4  50.0  55000.0   Bandung        S1             8

# %%
df_raw
# Out:
#      age   salary      city education  satisfaction
# 0   25.0  50000.0   Jakarta        S1             8
# 1   30.0  60000.0   Bandung        S2             9
# 2    NaN  75000.0   Jakarta        S1             7
# 3   45.0  80000.0  Surabaya        S3             9
# 4   50.0  55000.0   Bandung        S1             8
# 5  200.0  65000.0   Jakarta        S2             3
# 6   28.0  90000.0     Medan        S1             7
# 7   35.0      NaN   Bandung       NaN             8
# 8   29.0  72000.0   Jakarta        S1             9

# %%
df_cleaned = data_cleaner(
    data=df_raw,
    target_column='satisfaction'
)
# Out:
# =====================================================
# ||      NOVENTIS AUTOMATED DATA CLEANER      ||
# =====================================================
# Target column 'satisfaction' identified.
# STARTING NOVENTIS DATA CLEANER PIPELINE
# ==================================================
#
# Executing Step: IMPUTE...
# Step IMPUTE Complete.
#
# Executing Step: OUTLIER...
# Step OUTLIER Complete.
#
# Executing Step: ENCODE...
# ============================================================
# 🚀 NOVENTIS ENCODER - ANALYSIS REPORT
# ============================================================
# 📊 Analyzed 2 categorical columns
#
#
# 📋 ENCODING SUMMARY
# ----------------------------------------
#    OHE: 2 columns
#
# 📊 DETAILED COLUMN ANALYSIS
# ----------------------------------------
#    city:
#       Method: OHE
#       Unique values: 4
#       Target correlation: 0.000
#       Memory impact: 0.0 MB
#
#    education:
#       Method: OHE
#       Unique values: 3
#       Target correlation: 0.000
#       Memory impact: 0.0 MB
#
# ============================================================
# 🔄 Transforming data...
# ❌ Error encoding column 'city': name 'encoder' is not defined
# ❌ Error encoding column 'education': name 'encoder' is not defined
# ✅ Successfully transformed 0 columns
# Step ENCODE Complete.
#
# Executing Step: SCALE...
#
# 📋 SCALING SUMMARY
# ----------------------------------------
#    - STANDARD: 2 columns
#
# 📊 DETAILED REPORT
# ----------------------------------------
#   Column: age
#      - Method: STANDARD
#      - Reason: p-value 0.207 > 0.05
#      - Skewness: 0.51 | Outlier Ratio: 0.00%
#   Column: salary
#      - Method: STANDARD
#      - Reason: p-value 0.966 > 0.05
#      - Skewness: 0.08 | Outlier Ratio: 0.00%
# ============================================================
# Step SCALE Complete.
#
# PIPELINE FINISHED
# ==================================================
#
# ====================== DATA QUALITY REPORT ======================
#
# --- OVERALL DATA QUALITY SCORE ---
#   Final Quality Score: 66.67/100
#      - Completeness Score                 : 100.00     (Weight: 40%)
#      - Data Consistency Score             : 88.89      (Weight: 0%)
#      - Distribution Improvement Score     : 0.00       (Weight: 20%)
#      - Dimensionality Efficiency Score    : 0.00       (Weight: 10%)
#
# --- PIPELINE PROCESS SUMMARY ---
#   - Imputation: Successfully filled 3 missing values.
#   - Outliers: Removed 1 rows identified as outliers.
#   - Encoding: Transformed 2 categorical columns into 7 new features.
#   - Scaling: Standardized the scale for 2 numerical columns.
#
# --- AUTOMATIC DECISION DETAILS ---
#   - SCALING:
#     - Column 'age': Used 'STANDARD' because: p-value 0.207 > 0.05.
#     - Column 'salary': Used 'STANDARD' because: p-value 0.966 > 0.05.
#   - ENCODING:
#     - Column 'city': Selected method 'OHE'.
#     - Column 'education': Selected method 'OHE'.
#
# =================================================================

# %%
df_cleaned
# Out:
#         age    salary      city education
# 0 -1.143871 -1.506730   Jakarta        S1
# 1 -0.672172 -0.705145   Bandung        S2
# 2  1.686325  0.497233   Jakarta        S1
# 3  0.742927  0.898026  Surabaya        S3
# 4  1.214626 -1.105937   Bandung        S1
# 6 -0.860851  1.699611     Medan        S1
# 7 -0.200472 -0.033817   Bandung        S1
# 8 -0.766512  0.256758   Jakarta        S1

# %%
# Out:
# STARTING NOVENTIS DATA CLEANER PIPELINE
# ==================================================
#
# Executing Step: IMPUTE...
# Step IMPUTE Complete.
#
# Executing Step: OUTLIER...
# Step OUTLIER Complete.
#
# Executing Step: ENCODE...
# ============================================================
# 🚀 NOVENTIS ENCODER - ANALYSIS REPORT
# ============================================================
# 📊 Analyzed 2 categorical columns
#
#
# 📋 ENCODING SUMMARY
# ----------------------------------------
#    OHE: 2 columns
#
# 📊 DETAILED COLUMN ANALYSIS
# ----------------------------------------
#    city:
#       Method: OHE
#       Unique values: 4
#       Target correlation: 0.000
#       Memory impact: 0.0 MB
#
#    education:
#       Method: OHE
#       Unique values: 3
#       Target correlation: 0.000
#       Memory impact: 0.0 MB
#
# ============================================================
# 🔄 Transforming data...
# ❌ Error encoding column 'city': name 'encoder' is not defined
# ❌ Error encoding column 'education': name 'encoder' is not defined
# ✅ Successfully transformed 0 columns
# Step ENCODE Complete.
#
# Executing Step: SCALE...
#
# 📋 SCALING SUMMARY
# ----------------------------------------
#    - STANDARD: 2 columns
#
# 📊 DETAILED REPORT
# ----------------------------------------
#   Column: age
#      - Method: STANDARD
#      - Reason: p-value 0.207 > 0.05
#      - Skewness: 0.51 | Outlier Ratio: 0.00%
#   Column: salary
#      - Method: STANDARD
#      - Reason: p-value 0.966 > 0.05
#      - Skewness: 0.08 | Outlier Ratio: 0.00%
# ============================================================
# Step SCALE Complete.
#
# PIPELINE FINISHED
# ==================================================
#
# ====================== DATA QUALITY REPORT ======================
#
# --- OVERALL DATA QUALITY SCORE ---
#   Final Quality Score: 66.67/100
#      - Completeness Score                 : 100.00     (Weight: 40%)
#      - Data Consistency Score             : 88.89      (Weight: 0%)
#      - Distribution Improvement Score     : 0.00       (Weight: 20%)
#      - Dimensionality Efficiency Score    : 0.00       (Weight: 10%)
#
# --- PIPELINE PROCESS SUMMARY ---
#   - Imputation: Successfully filled 3 missing values.
#   - Outliers: Removed 1 rows identified as outliers.
#   - Encoding: Transformed 2 categorical columns into 7 new features.
#   - Scaling: Standardized the scale for 2 numerical columns.
#
# --- AUTOMATIC DECISION DETAILS ---
#   - SCALING:
#     - Column 'age': Used 'STANDARD' because: p-value 0.207 > 0.05.
#     - Column 'salary': Used 'STANDARD' because: p-value 0.966 > 0.05.
#   - ENCODING:
#     - Column 'city': Selected method 'OHE'.
#     - Column 'education': Selected method 'OHE'.
#
# =================================================================
#         age    salary      city education
# 0 -1.143871 -1.506730   Jakarta        S1
# 1 -0.672172 -0.705145   Bandung        S2
# 2  1.686325  0.497233   Jakarta        S1
# 3  0.742927  0.898026  Surabaya        S3
# 4  1.214626 -1.105937   Bandung        S1

# %%
df = pd.read_csv('../dataset_for_examples/AmesHousing.csv')

# %%
df_cleaned = data_cleaner(
    data=df,
    target_column='SalePrice'
)
# Out:
# =====================================================
# ||      NOVENTIS AUTOMATED DATA CLEANER      ||
# =====================================================
# Target column 'SalePrice' identified.
# STARTING NOVENTIS DATA CLEANER PIPELINE
# ==================================================
#
# Executing Step: IMPUTE...
# Step IMPUTE Complete.
#
# Executing Step: OUTLIER...
# Step OUTLIER Complete.
#
# Executing Step: ENCODE...
# ============================================================
# 🚀 NOVENTIS ENCODER - ANALYSIS REPORT
# ============================================================
# 📊 Analyzed 43 categorical columns
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_cleaned = data_cleaner(
#       2     data=df,
#       3     target_column='SalePrice'
#       4 )
#
# File ~/BCC/LaplaceProject/Noventis-Data/noventis/data_cleaner/auto.py:343, in data_cleaner(data, target_column, null_handling, outlier_handling, encoding, scaling, verbose, return_instance)
#     334 # 4. Initialize and Run the Main Cleaner
#     335 cleaner_instance = NoventisDataCleaner(
#     336     imputer_params=imputer_params,
#     337     outlier_params=outlier_params,
#    (...)
#     340     verbose=verbose
#     341 )
# --> 343 cleaned_df = cleaner_instance.fit_transform(X, y)
#     345 # --- BAGIAN RETURN YANG DIMODIFIKASI ---
#     346 if return_instance:
#
# File ~/BCC/LaplaceProject/Noventis-Data/noventis/data_cleaner/auto.py:97, in NoventisDataCleaner.fit_transform(self, X, y)
#      95          self.encoder_params['target_column'] = y.name
#      96     self.encoder_ = NoventisEncoder(**self.encoder_params)
# ---> 97     df_processed = self.encoder_.fit_transform(df_processed, y)
#      98     self.reports_['encode'] = self.encoder_.get_quality_report()
#     100 elif step == 'scale':
#
# File ~/BCC/LaplaceProject/Noventis-Data/noventis/data_cleaner/encoding.py:361, in NoventisEncoder.fit_transform(self, X, y)
#     360 def fit_transform(self, X: pd.DataFrame, y: Optional[pd.Series] = None) -> pd.DataFrame:
# --> 361     return self.fit(X, y).transform(X)
#
# File ~/BCC/LaplaceProject/Noventis-Data/noventis/data_cleaner/encoding.py:207, in NoventisEncoder.fit(self, X, y)
#     204     print("=" * 60 + "\n🚀 NOVENTIS ENCODER - ANALYSIS REPORT\n" + "=" * 60)
#     206 if self.method == 'auto':
# --> 207     self._fit_auto_mode(X, y)
#     208 else:
#     209     self._fit_manual_mode(X, y)
#
# File ~/BCC/LaplaceProject/Noventis-Data/noventis/data_cleaner/encoding.py:250, in NoventisEncoder._fit_auto_mode(self, X, y)
#     244     target_type = self._determine_target_type(y)
#     245     encoder = TargetEncoder(
#     246         cv=self.cv,
#     247         smooth=self.smooth,
#     248         target_type=target_type
#     249     )
# --> 250     encoder.fit(X[[col]], y)
#     252 elif encoding_method == 'binary':
#     253     encoder = BinaryEncoder()
#
# File ~/.conda/envs/noventis/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.conda/envs/noventis/lib/python3.10/site-packages/sklearn/preprocessing/_target_encoder.py:231, in TargetEncoder.fit(self, X, y)
#     214 @_fit_context(prefer_skip_nested_validation=True)
#     215 def fit(self, X, y):
#     216     """Fit the :class:`TargetEncoder` to X and y.
#     217
#     218     Parameters
#    (...)
#     229         Fitted encoder.
#     230     """
# --> 231     self._fit_encodings_all(X, y)
#     232     return self
#
# File ~/.conda/envs/noventis/lib/python3.10/site-packages/sklearn/preprocessing/_target_encoder.py:358, in TargetEncoder._fit_encodings_all(self, X, y)
#     352 # avoid circular import
#     353 from ..preprocessing import (
#     354     LabelBinarizer,
#     355     LabelEncoder,
#     356 )
# --> 358 check_consistent_length(X, y)
#     359 self._fit(X, handle_unknown="ignore", ensure_all_finite="allow-nan")
#     361 if self.target_type == "auto":
#
# File ~/.conda/envs/noventis/lib/python3.10/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1444, 2930]
