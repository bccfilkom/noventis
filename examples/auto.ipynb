# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path)

print('Successfully imported modules from data_cleaner!')
# Out:
# Successfully imported modules from data_cleaner!

# %%
import pandas as pd
import numpy as np
from noventis import data_cleaner


sample_data = {
    'age': [25, 30, np.nan, 45, 50, 200, 28, 35, 29],
    'salary': [50000, 60000, 75000, 80000, 55000, 65000, 90000, np.nan, 72000],
    'city': ['Jakarta', 'Bandung', 'Jakarta', 'Surabaya', 'Bandung', 'Jakarta', 'Medan', 'Bandung', 'Jakarta'],
    'education': ['S1', 'S2', 'S1', 'S3', 'S1', 'S2', 'S1', np.nan, 'S1'],
    'satisfaction': [8, 9, 7, 9, 8, 3, 7, 8, 9] 
}
# df_raw = pd.read_csv('../dataset_for_examples/AmesHousing.csv')

df_raw = pd.read_csv('dummy_classification_churn.csv')

# print("Raw Data:")
# df_raw.head()

# X = df_raw.drop('satisfaction', axis=1)
# y = df_raw['satisfaction']

# df_cleaned, dfisinstance = data_cleaner(
#     data=df_raw,
#     target_column='SalePrice',
#     return_instance=True,
# )


df_cleaned, dfisinstance = data_cleaner(
    data=df_raw,
    target_column='churn',
    return_instance=True,
)
# Out:
# Target column 'churn' identified.
# STARTING NOVENTIS DATA CLEANER PIPELINE
#
# Executing Step: IMPUTE...
# Step IMPUTE Complete.
#
# Executing Step: OUTLIER...
# Step OUTLIER Complete.
#
# Executing Step: ENCODE...
# Step ENCODE Complete.
#
# Executing Step: SCALE...
# Step SCALE Complete.
#
# PIPELINE FINISHED
# ...
#
# ====================== DATA QUALITY REPORT ======================
#   Final Quality Score: 99.12/100
#      - Completeness Score                 : 100.00     (Weight: 40%)
#      - Data Consistency Score             : 100.00     (Weight: 0%)
#      - Distribution Quality Score         : 95.62      (Weight: 20%)
#      - Feature Engineering Score          : 100.00     (Weight: 10%)
#
# PIPELINE PROCESS SUMMARY
#   - Imputation: Successfully filled 0 missing values.
#   - Outliers: Removed 390 rows identified as outliers.
#   - Encoding: Transformed 0 categorical columns into 0 new features.
#   - Scaling: Standardized the scale for 15 numerical columns.
#
# ...

# %%
dfisinstance.generate_html_report()
# Out:
#         <!DOCTYPE html>
#         <html lang="en">
#         <head>
#             <meta charset="UTF-8">
#             <meta name="viewport" content="width=device-width, initial-scale=1.0">
#             <title>Noventis Data Cleaning Report</title>
#             <style>
#                 @import url('https://fonts.googleapis.com/css2?family=Inter:wght@300;400;600;700;800&display=swap');
#
#                 #noventis-report-755a761d {
#                     --bg-dark-1: #0D1117;
#                     --bg-dark-2: #161B22;
#                     --bg-dark-3: #010409;
#                     --border-color: #30363D;
#                     --text-light: #C9D1D9;
#                     --text-muted: #8B949E;
#                     --primary-blue: #58A6FF;
#                     --primary-orange: #F78166;
#                     --success-green: #3FB950;
#                     --warning-yellow: #D29922;
#                     font-family: 'Inter', sans-serif;
# ...

# %%
dfisinstance._processed_df.head()
# Out:
#         Order       PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 147 -1.761417 -0.921709         -0.3      0.314286  0.228344      0.100741
# 148 -1.760103 -0.921703          0.0     -0.257143 -0.248879     -1.722392
# 149 -1.758790 -0.921051         -0.3     -0.257143  0.493854     -0.810826
# 150 -1.757477 -0.921050         -0.3      1.015714  0.477946     -0.810826
# 151 -1.756163 -0.921040          1.1      0.028571  1.256544     -0.810826
#
#      Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# 147           0.0   -0.406186       -1.121652      1.529745  ...
# 148           0.0   -0.517971       -1.267840      0.000000  ...
# 149           1.0   -0.667019       -1.462758      0.000000  ...
# 150           0.5   -0.555233       -1.316570      0.000000  ...
# 151           0.0   -0.443447       -1.170381      0.000000  ...
#
#      Sale Type_CWD  Sale Type_Con  Sale Type_ConLD  Sale Type_ConLI  \
# ...

# %%
import pandas as pd
import numpy as np
from noventis import data_cleaner


sample_data = {
    'age': [25, 30, np.nan, 45, 50, 200, 28, 35, 29],
    'salary': [50000, 60000, 75000, 80000, 55000, 65000, 90000, np.nan, 72000],
    'city': ['Jakarta', 'Bandung', 'Jakarta', 'Surabaya', 'Bandung', 'Jakarta', 'Medan', 'Bandung', 'Jakarta'],
    'education': ['S1', 'S2', 'S1', 'S3', 'S1', 'S2', 'S1', np.nan, 'S1'],
    'satisfaction': [8, 9, 7, 9, 8, 3, 7, 8, 9] 
}
df_raw = pd.DataFrame(sample_data)

print("Raw Data:")
df_raw.head()

# %%
df_raw

# %%
df_cleaned, dfisinstance = data_cleaner(
    data=df_raw,
    target_column='satisfaction',
    return_instance=True,
)

# %%
dfisinstance.plot_all_comparisons()

# %%
df_cleaned, dfisinstance = data_cleaner(
    data=df_raw,
    target_column='satisfaction',
    return_instance=True,
    null_handling='mode',
    outlier_handling='dropping',
    encoding='ohe',
    scaling='standard',
)

# %%
df = pd.read_csv('../dataset_for_examples/AmesHousing.csv')

# %%
df_cleaned = data_cleaner(
    data=df,
    target_column='SalePrice'
)

# %%
df_cleaned, dfisinstance = data_cleaner(
    data=df,
    target_column='SalePrice',
    return_instance=True,
)

# %%
dfisinstance.generate_html_report()
