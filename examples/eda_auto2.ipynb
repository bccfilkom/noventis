# %%
import sys
import os
import pandas as pd

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from noventis.eda_auto import EDAAnalyzer 
print('Successfully imported modules!')
# Out:
# Successfully imported modules!

# %%
df_coba = pd.read_csv('../dataset_for_examples/GenderClassifier.csv', encoding='latin1')

# %%
analyzer = EDAAnalyzer(df_coba, target='gender')

analyzer.run()
# Out:
# Generating EDA report, please wait...
# Report generated successfully. Displaying below.
#         <!DOCTYPE html><html lang="en"><head><meta charset="UTF-8"><title>Automated EDA Report</title>
#         <style>
#             @import url('https://fonts.googleapis.com/css2?family=Roboto:wght@300;400;700&family=Exo+2:wght@600;800&display=swap');
#             :root {
#                 --bg-dark-1: #0D1117; --bg-dark-2: #161B22; --bg-dark-3: #010409; --border-color: #30363D;
#                 --text-light: #C9D1D9; --text-muted: #8B949E; --primary-blue: #58A6FF; --primary-orange: #F78166;
#                 --font-main: 'Roboto', sans-serif; --font-header: 'Exo 2', sans-serif;
#             }
#             body { font-family: var(--font-main); background-color: var(--bg-dark-3); color: var(--text-light); margin: 0; padding: 1.5rem; }
# ...
